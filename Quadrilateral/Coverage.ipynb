# %%
import os

# %%
def line_coverage():
    os.system("clang++ -std=c++11 -fprofile-instr-generate -fcoverage-mapping main.cpp QuadrilateralClassifier.cpp -o main")
    os.system("rm -f *.profdata")
    os.system("mkdir profile")
    os.system("touch ./profile/main.profdata")
    os.system("touch ./default.profraw")
    os.system("rm ./profile/.DS_Store.profraw")
    os.system("rm ./profile/.DS_Store.profdata")
    prev = "main"
    
    for (root,dirs,files) in os.walk("input", topdown=True):
        for name in files:
            filename = root+"/"+name
            os.system("LLVM_PROFILE_FILE=\"./profile/"+prev+".profraw\" ./main "+filename)
            print("LLVM_PROFILE_FILE=\"./profile/"+prev+".profraw\" ./main "+filename)
            os.system("LLVM_PROFILE_FILE=\"./profile/"+name[0:-4]+".profraw\" ./main "+filename+"> output.txt")
            os.system("xcrun llvm-profdata merge -sparse ./profile/"+prev+".profdata ./profile/"+name[0:-4]+".profraw -o ./profile/"
                      +name+".profdata")
    os.system("xcrun llvm-cov show ./main -instr-profile=./profile/"+prev+".profdata > coverage.txt")

# %%
line_coverage()
# Out:
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four37.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four23.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four22.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four36.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four20.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four34.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four35.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four21.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four19.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four25.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four31.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four30.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four24.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four18.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four32.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four26.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four27.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four33.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four54.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four40.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four68.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four97.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four83.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four82.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four96.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four69.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four41.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four55.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four43.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four57.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four80.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four94.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four9.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four8.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four95.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four81.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four56.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four42.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four46.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four52.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four85.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four91.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four90.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four84.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four53.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four47.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four79.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four51.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four45.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four92.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four86.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four87.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four93.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four44.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four50.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four78.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four75.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four61.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four49.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four3.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four2.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four48.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four60.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four74.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four62.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four76.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four0.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four89.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four88.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four1.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four77.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four63.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four67.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four73.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four98.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four5.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four4.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four99.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four72.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four66.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four58.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four70.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four64.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four6.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four7.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four65.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four71.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four59.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four16.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four17.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four15.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four29.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four28.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four14.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four38.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four10.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four11.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four39.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four13.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/error_four/error_four12.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square15.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square29.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square28.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square14.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square16.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square17.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square13.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square12.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square38.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square10.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square11.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square39.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square76.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square62.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square89.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square2.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square3.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square88.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square63.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square77.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square61.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square75.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square49.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square1.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square48.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square74.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square60.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square58.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square64.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square70.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square4.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square5.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square71.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square65.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square59.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square73.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square67.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square98.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square7.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square6.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square99.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square66.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square72.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square57.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square43.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square94.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square80.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square81.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square95.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square42.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square56.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square40.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square54.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square68.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square83.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square97.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square8.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square100.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square9.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square96.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square82.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square69.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square55.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square41.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square79.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square45.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square51.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square86.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square92.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square93.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square87.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square50.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square44.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square78.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square52.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square46.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square91.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square85.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square84.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square90.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square47.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square53.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square34.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square20.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square21.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square35.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square23.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square37.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square36.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square22.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square26.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square32.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square33.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square27.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square19.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square31.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square25.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square24.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square30.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/square/square18.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle6.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle96.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle82.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle55.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle41.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle69.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle192.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle186.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle179.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle151.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle145.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle144.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle150.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle178.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle187.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle193.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle68.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle40.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle54.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle83.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle97.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle7.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle5.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle81.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle95.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle42.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle56.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle185.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle191.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle146.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle152.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle153.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle147.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle190.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle184.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle57.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle43.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle94.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle80.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle4.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle84.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle90.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle47.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle53.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle180.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle194.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle143.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle157.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle156.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle142.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle195.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle181.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle52.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle46.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle91.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle85.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle1.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle3.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle93.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle87.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle78.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle50.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle44.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle183.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle154.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle140.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle168.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle169.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle141.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle155.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle182.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle196.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle45.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle51.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle79.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle86.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle92.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle2.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle36.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle22.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle132.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle126.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle127.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle133.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle23.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle37.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle21.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle35.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle119.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle125.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle131.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle130.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle124.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle118.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle34.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle20.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle18.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle24.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle30.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle120.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle134.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle108.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle109.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle135.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle121.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle31.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle25.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle19.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle33.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle27.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle137.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle123.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle122.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle136.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle26.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle32.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle17.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle113.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle107.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle106.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle112.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle16.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle14.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle28.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle138.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle104.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle110.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle111.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle105.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle139.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle29.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle15.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle39.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle11.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectangle101.txt
# LLVM_PROFILE_FILE="./profile/main.profraw" ./main input/rectangle/rectang